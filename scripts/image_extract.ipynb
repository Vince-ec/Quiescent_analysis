# %%
import galaxy_extract as ge
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
from glob import glob
sea.set(style='white')
sea.set(style='ticks')
sea.set_style({"xtick.direction": "in","ytick.direction": "in"})
colmap = sea.cubehelix_palette(12, start=2, rot=.2, dark=0, light=1.1, as_cmap=True)
# Out:
# /Users/vestrada/miniconda2/envs/astroconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
qgDB = pd.read_pickle('../data/quiescent_gal_DB.pkl')
gsDB = qgDB[qgDB['spec'] == True]

# %%
flt_files = []
flt_pos = np.zeros([len(qgDB.index),2])

for i in qgDB.index:
    if i in gsDB.index:
        flt_fn , flt_pos[i] =ge.FLT_search(gsDB['ra'][i],gsDB['dec'][i])
        flt_files.append(flt_fn)
    else:
        flt_files.append('none')

# %%
gsDB
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gids</th>
#       <th>ids</th>
#       <th>redshift</th>
#       <th>hmag</th>
#       <th>ra</th>
#       <th>dec</th>
#       <th>agn</th>
#       <th>in_data</th>
#       <th>spec</th>
#       <th>flt_files</th>
#       <th>flt_xpos</th>
#       <th>flt_ypos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>43</th>
#       <td>n14713</td>
#       <td>14713</td>
#       <td>1.134</td>
#       <td>22.557517</td>
#       <td>189.236333</td>
#       <td>62.214608</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>../../../Clear_data/flt_files/icat12tqq_flt.fits</td>
#       <td>480.823147</td>
#       <td>636.879341</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>n15616</td>
#       <td>15616</td>
#       <td>1.250</td>
#       <td>23.162718</td>
#       <td>189.238403</td>
#       <td>62.218809</td>
# ...

# %%
hd_path='../../../../../Volumes/Vince_research/goods_4.4/'

# %%
gal_img = ge.Image_pull(gsDB['flt_files'][230],hd_path + 'goodss_v4.4/goodss-F105W-astrodrizzle-v4.4_drz_sci.fits',
              hd_path + 'goodss_v4.4/goodss-F105W-astrodrizzle-v4.4_drz_seg.fits',
              '../../../Clear_data/goodss_mosaic/goodss_3dhst.v4.3.cat', gsDB['ids'][230])
# Out:
# Image cutout: x=slice(6809, 10129, None), y=slice(13005, 16619, None)
# Using default C-based coordinate transformation...
# Image cutout: x=slice(6809, 10129, None), y=slice(13005, 16619, None)
# ../../../Clear_data/flt_files/icxt34epq_flt.fits / Pad ref HDU with 50 pixels
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...

# %%
# %matplotlib inline

plt.figure(figsize=[8,8])
plt.imshow(gal_img.cutout,interpolation='Nearest',cmap=colmap,origin='lower')
plt.show()

plt.figure(figsize=[8,8])
plt.imshow(cln_cutout,interpolation='Nearest',cmap=colmap,origin='lower')
plt.show()

# %%
plt.figure(figsize=[12,5])
plt.plot(sum(gal_img.cutout))
plt.show()
plt.close()


plt.figure(figsize=[12,5])
plt.plot(sum(cln_cutout))
plt.show()
plt.close()

# %%
cln_cutout = np.array(gal_img.cutout)

cln_cutout[gal_img.cutout < 1E-20]= 0
